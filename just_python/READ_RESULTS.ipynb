# %%
import pandas as pd

import os

import matplotlib.pyplot as plt

import seaborn as sns

import time

os.chdir('..')

# %%
TEST = pd.read_parquet(r"output\TEST.parquet")

print(TEST['container_id'].value_counts())

print('\nWe can see that tasks are done in parallel by workers')
# Out:
# container_id
# 66c3a4a487b4    28030
# 47d06bb7b1a7    26013
# 01a0112c1a3c    23987
# 32cd981dbfa1    21970
# Name: count, dtype: int64
#
# We can see that tasks are done in parallel by workers

# %%
TIME = pd.read_parquet(r"output\TIME.parquet")

TIME = TIME[TIME['executor_memory'].notna() & TIME['executor_cores'].notna()]

TIME.loc[:, 'executor_memory'] = TIME['executor_memory'].apply(lambda x: x.replace('g',''))

TIME = TIME[['executor_memory', 'executor_cores', 'computation_seconds']].astype(float)

TIME.loc[TIME['Model'] == 'ANN'].pivot_table(index = 'executor_memory', columns = 'executor_cores', values = 'computation_seconds', aggfunc='mean')
# Out:
# executor_cores          4.0         5.0        7.0
# executor_memory
# 4.0              223.413391  201.527893        NaN
# 5.0               82.618317         NaN        NaN
# 6.0               81.730034         NaN        NaN
# 7.0              167.964493         NaN  35.517891
# 8.0               52.342945         NaN        NaN
# 9.0               75.780922         NaN        NaN
# 10.0              85.891243         NaN        NaN
# 11.0             164.078522         NaN        NaN

# %%
ASJ = pd.read_parquet(r"output\ASJ.parquet")

ASJ
# Out:
#       data_vector  query_vector  Euclidean_Distance  query_type     C    v  \
# 0           664.0           2.0            0.000000         2.0   6.0 -1.0
# 1          6298.0           2.0            3.713457         2.0   6.0 -1.0
# 2          8329.0           2.0            3.729755         2.0   6.0 -1.0
# 3          5640.0           2.0            4.275297         2.0   0.0 -1.0
# 4           613.0           2.0            4.352063         2.0   6.0 -1.0
# ...           ...           ...                 ...         ...   ...  ...
# 7295        590.0          92.0            8.154801         2.0   0.0 -1.0
# 7296       4487.0          92.0            8.157404         2.0   4.0 -1.0
# 7297       6511.0          92.0            8.163771         2.0   1.0 -1.0
# 7298       3290.0          92.0            8.163857         2.0   1.0 -1.0
# 7299       2872.0          92.0            8.183878         2.0  26.0 -1.0
#
#              l         T         r
# 0     0.029560  0.077597  0.077597
# 1     0.029560  0.039120  0.077597
# 2     0.029560  0.039150  0.077597
# 3     0.029560  0.073084  0.077597
# 4     0.029560  0.061167  0.077597
# ...        ...       ...       ...
# 7295  0.028287  0.038598  0.047144
# 7296  0.028287  0.034616  0.047144
# 7297  0.028287  0.043553  0.047144
# 7298  0.028287  0.032740  0.047144
# 7299  0.028287  0.042570  0.047144
#
# [7300 rows x 9 columns]

# %%
ANN = pd.read_parquet(r"output\ANN.parquet")

ANN
# Out:
#       data_vector  query_vector  Euclidean_Distance  query_type     C    v  \
# 0           178.0          89.0            0.000000         2.0  27.0 -1.0
# 1          1023.0          89.0            5.715580         2.0   1.0 -1.0
# 2          4842.0          89.0            5.823170         2.0   6.0 -1.0
# 3            23.0          89.0            6.150796         2.0   4.0 -1.0
# 4          4790.0          89.0            6.151405         2.0   6.0 -1.0
# ...           ...           ...                 ...         ...   ...  ...
# 9995       9566.0          29.0            7.764924         2.0   1.0 -1.0
# 9996       3499.0          29.0            7.790370         2.0   1.0 -1.0
# 9997       3517.0          29.0            7.797029         2.0   6.0 -1.0
# 9998       5966.0          29.0            7.807009         2.0   1.0 -1.0
# 9999       5696.0          29.0            7.809888         2.0   0.0 -1.0
#
#              l         T         r
# 0     0.021556  0.021556  0.039832
# 1     0.021556  0.024074  0.039832
# 2     0.021556  0.033743  0.039832
# 3     0.021556  0.036482  0.039832
# 4     0.021556  0.033362  0.039832
# ...        ...       ...       ...
# 9995  0.081991  0.091079  0.095683
# 9996  0.081991  0.091731  0.095683
# 9997  0.081991  0.093015  0.095683
# 9998  0.081991  0.095221  0.095683
# 9999  0.081991  0.084860  0.095683
#
# [10000 rows x 9 columns]

# %%
BFNN = pd.read_parquet('output\BRUTE_FORCE.parquet').astype(float)

BFNN
# Out:
#       query_vector      Distance  data_vector  query_type      C    v    l  \
# 0              0.0  8.429370e-08       8915.0         0.0    6.0 -1.0 -1.0
# 1              0.0  4.917437e+00       1069.0         0.0   27.0 -1.0 -1.0
# 2              0.0  5.552160e+00       9292.0         0.0   24.0 -1.0 -1.0
# 3              0.0  5.623654e+00        651.0         0.0    5.0 -1.0 -1.0
# 4              0.0  5.669254e+00       3744.0         0.0    1.0 -1.0 -1.0
# ...            ...           ...          ...         ...    ...  ...  ...
# 9995          99.0  8.658940e+00        438.0         1.0  101.0  2.0 -1.0
# 9996          99.0  8.665779e+00        527.0         1.0    1.0  2.0 -1.0
# 9997          99.0  8.666491e+00          7.0         1.0   34.0  2.0 -1.0
# 9998          99.0  8.683486e+00        607.0         1.0    1.0  2.0 -1.0
# 9999          99.0  8.687438e+00        356.0         1.0    1.0  2.0 -1.0
#
#              T    r
# 0     0.056623 -1.0
# 1     0.008135 -1.0
# 2     0.004283 -1.0
# 3     0.023121 -1.0
# 4     0.035148 -1.0
# ...        ...  ...
# 9995  0.058479 -1.0
# 9996  0.000010 -1.0
# 9997  0.092503 -1.0
# 9998  0.010683 -1.0
# 9999  0.010964 -1.0
#
# [10000 rows x 9 columns]

# %%
results = BFNN.set_index(['query_vector', 'data_vector']).join(ASJ.set_index(['query_vector', 'data_vector']), lsuffix='_BF' ,rsuffix='_ASJ', how='inner')

results.shape[0]/BFNN.shape[0]
# Out:
# 0.0073

# %%
results = BFNN.set_index(['query_vector', 'data_vector']).join(ANN.set_index(['query_vector', 'data_vector']), lsuffix='_BF' ,rsuffix='_ASJ', how='inner')

results.shape[0]/BFNN.shape[0]
# Out:
# 0.276
